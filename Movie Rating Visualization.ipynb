# %% [markdown]
# # Movie Rating Visulization

# %%
import pandas as pd 
import os
os.getcwd()
# Out:
# 'C:\\Users\\prath\\Desktop\\Python course'

# %%
Data = pd.read_csv("Movie-Ratings.csv")

# %%
Data.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
len(Data)
# Out:
# 559

# %%
len(Data.columns)
# Out:
# 6

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                         559 non-null object
# Genre                        559 non-null object
# Rotten Tomatoes Ratings %    559 non-null int64
# Audience Ratings %           559 non-null int64
# Budget (million $)           559 non-null int64
# Year of release              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
Data.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
Data.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
Data.columns =['Film', 'Genre', 'CriticRatings', 'AudienceRatings',
       'Budget', 'Year']

# %%
Data.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  Budget  \
# 0  (500) Days of Summer      Comedy             87               81       8
# 1            10,000 B.C.  Adventure              9               44     105
# 2             12 Rounds      Action             30               52      20
# 3              127 Hours  Adventure             93               84      18
# 4              17 Again      Comedy             55               70      20
#
#    Year
# 0  2009
# 1  2008
# 2  2009
# 3  2010
# 4  2009

# %%
#changing the types
Data["Film"] = Data["Film"].astype("category")
Data["Genre"] = Data["Genre"].astype("category")
Data["Year"] = Data["Year"].astype("category")

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# CriticRatings      559 non-null int64
# AudienceRatings    559 non-null int64
# Budget             559 non-null int64
# Year               559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
# accecc unique values
Data["Genre"].cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
Data.describe()
# Out:
#        CriticRatings  AudienceRatings      Budget
# count     559.000000       559.000000  559.000000
# mean       47.309481        58.744186   50.236136
# std        26.413091        16.826887   48.731817
# min         0.000000         0.000000    0.000000
# 25%        25.000000        47.000000   20.000000
# 50%        46.000000        58.000000   35.000000
# 75%        70.000000        72.000000   65.000000
# max        97.000000        96.000000  300.000000

# %% [markdown]
# # JointPlot()

# %%
import matplotlib 
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

plt.rcParams["figure.figsize"] = 10,6

# %%
vis1 = sns.jointplot(data=Data, x= "CriticRatings", y = "AudienceRatings")

# %%
vis1 = sns.jointplot(data=Data, x= "CriticRatings", y = "AudienceRatings", kind= "hex" )

# %%
vis1 = sns.jointplot(data=Data, x= "Budget", y = "AudienceRatings", kind= "kde")

# %% [markdown]
# # sns.displot vs plt.Hist()

# %% [markdown]
# ---

# %%
sns.set_style("darkgrid")
vis3 = sns.distplot (Data.AudienceRatings,rug=False)

# %%
vis4 = sns.distplot (Data.CriticRatings,rug=False)

# %%
x=Data.AudienceRatings
y= Data.CriticRatings
vis5 = plt.scatter(x = Data.CriticRatings, y= Data.AudienceRatings,alpha=0.5)
plt.legend(loc = "upper left",bbox_to_anchor = (1,1) )
plt.show()

# %%
vis5 = plt.hist(Data.CriticRatings, color = "red",edgecolor='black')

# %%
vis5 = plt.hist(Data.AudienceRatings, edgecolor='black' )

# %%
Data.Genre.unique()
# Out:
# [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]
# Categories (7, object): [Comedy, Adventure, Action, Horror, Drama, Romance, Thriller]

# %%
Data.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'Budget', 'Year'], dtype='object')

# %% [markdown]
# ## Stacked Histogram

# %% [markdown]
# ---

# %%
# chat 3
# stacked histogram
plt.hist(Data.Budget, edgecolor='black')
plt.show()

# %%
# Budget for a certain gerne
Data.Genre == "Drama"
Data[Data.Genre == "Drama"]
plt.hist(Data[Data.Genre == "Drama"].Budget, bins= 15,edgecolor='black')
plt.hist(Data[Data.Genre == "Thriller"].Budget, bins= 15,edgecolor='black')
plt.hist(Data[Data.Genre == "Romance"].Budget, bins= 15,edgecolor='black')
plt.hist(Data[Data.Genre == "Adventure"].Budget, bins= 15,edgecolor='black')
plt.legend(loc = "upper left",bbox_to_anchor = (1,1) )
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.hist([Data[Data.Genre == "Drama"].Budget, \
         Data[Data.Genre == "Thriller"].Budget,\
         Data[Data.Genre == "Action"].Budget],
         bins= 15,edgecolor='black', stacked = True )
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# making it easier by creating a function
list1 = list()
mylable =  list()
for gen in Data.Genre.unique():
    list1.append(Data[Data.Genre == gen].Budget)
    mylable.append(gen)
plt.hist(list1,  bins= 15,edgecolor='black', stacked = True, rwidth= 1, label = mylable)
plt.legend(loc = "upper left",bbox_to_anchor = (1,1) )
plt.show()

# %% [markdown]
# # sns.kdeplot()

# %% [markdown]
# ---

# %%
#chat4
cl = sns.lmplot( data = Data,x="CriticRatings", y="AudienceRatings", hue = "Genre", fit_reg=False, size= 8)

# %%
Data.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'Budget', 'Year'], dtype='object')

# %%
k = sns.kdeplot(Data.AudienceRatings, Data.CriticRatings, shade=True, legend=True,  shade_lowest=False)

# %%
k = sns.kdeplot(Data.AudienceRatings, Data.CriticRatings, shade=True, legend=True,  shade_lowest=False, cmap ="Reds")
k = sns.kdeplot(Data.AudienceRatings, Data.CriticRatings, cmap ="Reds")

# %% [markdown]
# # Subplots

# %%
 f,axes = plt.subplots(1,2, figsize = (10,5), sharex= True, sharey =True)
k1 = sns.kdeplot( Data.AudienceRatings, Data.Budget, ax= axes[0])
k3 = sns.kdeplot( Data.CriticRatings, Data.Budget, ax= axes[1])
k1.set(xlim =( -20,130))
k1.set(ylim =( -20,200 ))
# Out:
# [(-20, 200)]

# %%
f,axes = plt.subplots(1,3, figsize = (15,5))
k2 = sns.kdeplot( Data.AudienceRatings, Data.Year,ax= axes[0])
k4 = sns.kdeplot( Data.CriticRatings, Data.Year, ax= axes[1])
k5 = sns.kdeplot(Data.Budget, Data.Year, ax= axes[2])
#k2.set(xlim =( -20,130))
#k2.set(ylim =( -20,200 ))

# %% [markdown]
# ## Violinplots vs Boxplots

# %% [markdown]
# ---

# %%
w = sns.violinplot(data=Data, x="Genre", y= "CriticRatings")

# %%
w2 = sns.boxplot(data=Data, x="Genre", y= "CriticRatings")

# %%
# filter by gerne
w2 = sns.boxplot(data=Data[Data.Genre == "Drama"], x="Year", y= "CriticRatings" )

# %%
w4 = sns.violinplot(data=Data[Data.Genre == "Drama"], x="Year", y= "CriticRatings" )

# %% [markdown]
# # Facid Grid

# %%
g= sns.FacetGrid( data = Data , row="Genre", col="Year", hue="Genre")
kwargs =dict (s=50 , linewidth = 0.5, edgecolor ="black")
g = g.map( plt.scatter,"CriticRatings" ,"AudienceRatings", **kwargs)
g.set(xlim = (0,100), ylim =(0,100))
for ax in g.axes.flat:
    ax.plot((0,100),(0,100), c= "gray" , ls = "--")
g.add_legend()

# %%
g= sns.FacetGrid( data = Data , row="Genre", col="Year", hue="Genre")
g = g.map( plt.hist,"Budget")

# %% [markdown]
# # Creating a dashboard

# %%
import matplotlib 
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
plt.rcParams["figure.figsize"] = 10,6

# %%
sns.set_style("darkgrid")
f, axes = plt.subplots(2,2, figsize = (15,10))
k1 = sns.kdeplot( Data.AudienceRatings, Data.Budget, ax= axes[0,0])
k3 = sns.kdeplot( Data.CriticRatings, Data.Budget, ax= axes[0,1])
w4 = sns.violinplot(data=Data[Data.Genre == "Drama"], x="Year", y= "CriticRatings" , ax= axes[1,0])

k = sns.kdeplot(Data.AudienceRatings, Data.CriticRatings, shade=True, legend=True,\
                shade_lowest=False, cmap ="Reds" , ax = axes[1,1])
k = sns.kdeplot(Data.AudienceRatings, Data.CriticRatings, cmap ="Reds",  ax = axes[1,1])

k1.set(xlim =( -20,130))
k1.set(ylim =( -20,200 ))
# Out:
# [(-20, 200)]

# %% [markdown]
# # Domestic Gross by Gerne with New Movie Data Set

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Import the data
mov = pd.read_csv('Movie_Analysis.csv', encoding = 'latin1')
mov.head()
# Out:
#   Day of Week                 Director   Genre        Movie Title  \
# 0      Friday                Brad Bird  action       Tomorrowland
# 1      Friday              Scott Waugh  action     Need for Speed
# 2      Friday           Patrick Hughes  action  The Expendables 3
# 3      Friday  Phil Lord, Chris Miller  comedy     21 Jump Street
# 4      Friday          Roland Emmerich  action   White House Down
#
#   Release Date               Studio Adjusted Gross ($mill)  Budget ($mill)  \
# 0   22/05/2015  Buena Vista Studios                  202.1           170.0
# 1   14/03/2014  Buena Vista Studios                  204.2            66.0
# 2   15/08/2014            Lionsgate                  207.1           100.0
# 3   16/03/2012                 Sony                  208.8            42.0
# 4   28/06/2013                 Sony                  209.7           150.0
#
#   Gross ($mill)  IMDb Rating  MovieLens Rating Overseas ($mill)  Overseas%  \
# ...

# %%
# Exploring the dataset
len(mov)
mov.columns = ['Day', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate',
       'Studio', 'AdjustedGross', 'Budget', 'Gross',
       'IMDbRating', 'MovieLensRating', 'Overseas', 'Overseas%',
       'Profit', 'Profit%', 'Runtime', 'US',
       'Gross%']
mov.columns
# Out:
# Index(['Day', 'Director', 'Genre', 'MovieTitle', 'ReleaseDate', 'Studio',
#        'AdjustedGross', 'Budget', 'Gross', 'IMDbRating', 'MovieLensRating',
#        'Overseas', 'Overseas%', 'Profit', 'Profit%', 'Runtime', 'US',
#        'Gross%'],
#       dtype='object')

# %%
# Checking the summary of the dataframe
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
# Day                608 non-null object
# Director           608 non-null object
# Genre              608 non-null object
# MovieTitle         608 non-null object
# ReleaseDate        608 non-null object
# Studio             608 non-null object
# AdjustedGross      608 non-null object
# Budget             608 non-null float64
# Gross              608 non-null object
# IMDbRating         608 non-null float64
# MovieLensRating    608 non-null float64
# Overseas           608 non-null object
# Overseas%          608 non-null float64
# Profit             608 non-null object
# Profit%            608 non-null float64
# Runtime            608 non-null int64
# US                 608 non-null float64
# Gross%             608 non-null float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 85.6+ KB

# %%
# Checking the structure of the dataframe
mov.describe()
# Out:
#            Budget  IMDbRating  MovieLensRating   Overseas%       Profit%  \
# count  608.000000  608.000000       608.000000  608.000000    608.000000
# mean    92.467928    6.923849         3.340378   57.698849    719.278783
# std     59.421407    0.925890         0.454071   12.334237   1942.807248
# min      0.600000    3.600000         1.490000   17.200000      7.700000
# 25%     45.000000    6.375000         3.037500   49.900000    201.850000
# 50%     80.000000    6.900000         3.365000   58.200000    338.550000
# 75%    130.000000    7.600000         3.672500   66.300000    650.100000
# max    300.000000    9.200000         4.500000  100.000000  41333.300000
#
#           Runtime          US      Gross%
# count  608.000000  608.000000  608.000000
# mean   117.781250  167.135197   42.301151
# std     23.179122   92.465903   12.334237
# min     30.000000    0.000000    0.000000
# 25%    100.000000  106.950000   33.700000
# 50%    116.000000  141.700000   41.800000
# ...

# %%
# Exploreing the categorical variable Studio, used in the assignment
mov.Studio = mov.Studio.astype("category")

# %%
# Exploring the categorical variable Studio, used in the assignment
mov.Genre._()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e8d39895d9d8> in <module>()
#       1 # Exploring the categorical variable Studio, used in the assignment
# ----> 2 mov.Genre._()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute '_'

# %%
# Filteing the dataframe by genre
mov2 = mov[(mov.Genre == 'action') | (mov.Genre == 'adventure') | (mov.Genre == 'animation') | (mov.Genre == 'comedy') | (mov.Genre == 'drama')]

# %%
# Filtering the dataframe by studio
mov3 = mov2[(mov2.Studio == 'Buena Vista Studios') | (mov2.Studio == 'Fox') | (mov2.Studio == 'Paramount Pictures') | (mov2. Studio == 'Sony') | (mov2.Studio == 'Universal') | (mov2.Studio == 'WB')]

# %%
# Checking how the filters worked
print (mov.Genre.unique())
print (mov.Studio.unique())
print (len(mov))
# Out:
# ['action' 'comedy' 'adventure' 'horror' 'animation' 'biography' 'drama'
#  'musical' 'sci-fi' 'crime' 'romance' 'fantasy' 'mystery' 'thriller'
#  'documentary']
# [Buena Vista Studios, Lionsgate, Sony, Universal, Paramount Pictures, ..., Vestron Pictures, MGM, Orion, IFC, New Market Films]
# Length: 36
# Categories (36, object): [Buena Vista Studios, Lionsgate, Sony, Universal, ..., MGM, Orion, IFC, New Market Films]
# 608

# %%
# Defineing the style
sns.set(style="darkgrid", palette="muted", color_codes=True)
plt.rcParams["figure.figsize"] = 10,10

# Ploting the boxsplots
ax = sns.boxplot(data=mov, x='Genre', y='Gross%', orient='v', color='lightgray', showfliers=False)
plt.setp(ax.artists, alpha=0.5)

# Adding in points to show each observation
sns.stripplot(x='Genre', y='Gross%', data=mov, jitter=True, size=6, linewidth=0, hue = 'Studio', alpha=0.7)

ax.axes.set_title('Domestic Gross by Genre',fontsize=30)
ax.set_xlabel('Genre',fontsize=20)
ax.set_ylabel('Gross%',fontsize=20)

# Defineing where to place the legend
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.
         )
